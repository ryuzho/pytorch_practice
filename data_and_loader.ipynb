# %%
cd /content/drive/MyDrive/pytorch_practice
# Out:
# /content/drive/MyDrive/pytorch_practice

# %%
# !git config --global user.email 'ryuzho@github.com'
# !git config --global user.name 'ryuzho'
# !git add .
# !git status
# !git commit -m 'data_loader_init'
# !git push
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Changes to be committed:
#   (use "git reset HEAD <file>..." to unstage)
#
# 	new file:   data_and_loader.ipynb
# 	modified:   tensor.ipynb
#
# [main 10562e2] data_loader_init
#  2 files changed, 2 insertions(+), 1 deletion(-)
#  create mode 100644 data_and_loader.ipynb
#  rewrite tensor.ipynb (94%)
# Counting objects: 4, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 1.83 KiB | 624.00 KiB/s, done.
# Total 4 (delta 1), reused 0 (delta 0)
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/ryuzho/pytorch_practice.git
#    f88d3d1..10562e2  main -> main
