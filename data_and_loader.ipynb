# %%
cd /content/drive/MyDrive/pytorch_practice
# !git config --global user.email 'ryuzho@github.com'
# !git config --global user.name 'ryuzho'
# !git add .
# !git status
# !git commit -m 'data_loader_init'
# !git push
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9529b44db58f> in <module>()
# ----> 1 cd /content/drive/MyDrive/pytorch_practice
#       2 get_ipython().system("git config --global user.email 'ryuzho@github.com'")
#       3 get_ipython().system("git config --global user.name 'ryuzho'")
#       4 get_ipython().system('git add .')
#       5 get_ipython().system('git status')
#
# NameError: name 'cd' is not defined
